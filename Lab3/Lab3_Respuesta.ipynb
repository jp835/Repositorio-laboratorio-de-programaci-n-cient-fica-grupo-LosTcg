# %% [markdown]
# <h1><center>Laboratorio 3: La desperación de Mr. Cheems 🐼</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2025</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Juan Muñoz
# - Nombre de alumno 2: Arturo Amberg

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Repositorio](https://github.com/jp835/Repositorio-laboratorio-de-programaci-n-cient-fica-grupo-LosTcg.git)

# %% [markdown]
# ## Temas a tratar
# - Aplicar Pandas para obtener características de un DataFrame.
# - Aplicar Pipelines y Column Transformers
#
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda **fuertemente** asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.
#
# ### Objetivos principales del laboratorio
# - Comprender cómo aplicar pipelines de Scikit-Learn para generar procesos más limpios en Feature Engineering.
#
# El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `numpy`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre arreglos (*o tensores*).

# %% [markdown]
# ## Descripción del laboratorio.

# %% [markdown]
# ### Importamos librerias utiles 😸

# %%
# Libreria Core del lab.
import numpy as np
import pandas as pd
import datetime
from IPython.display import HTML

# Libreria para plotear (En colab esta desactualizado plotly)
#!pip install --upgrade plotly
import plotly.express as px
import plotly.graph_objects as go

# Librerias utiles
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Feature engineering en datos de retail 🛍️

# %% [markdown]
# ### 0. Cargar Dataset

# %% [markdown]
# <p align="center">
#   <img width=300 src="https://s1.eestatic.com/2018/04/14/social/la_jungla_-_social_299733421_73842361_854x640.jpg">
# </p>

# %% [markdown]
# Mr. Cheems, gerente de una cotizada tienda de retail en Europa, les solicita si pueden analizar los datos de algunas de sus tiendas. En una reunión, Mr Cheems le comenta que la calidad de sus datos no es muy buena, por lo que le solicita a usted que limpie su base de datos y cree nuevos atributos relevantes para el negocio.
#
# Por ello, el área de ventas les entrega archivo llamado `online_retail_data.pickle` el cual usted decide cargar a continuación.

# %%
# Path
path = 'online_retail_data.pickle'

# Base de datos
df_retail = pd.read_pickle(path)
print('Shape:', df_retail.shape)
df_retail.head(10)
# Out:
# Shape: (400947, 8)
#     Invoice StockCode                          Description  Quantity  \
# 0  ID489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1  ID489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2  ID489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3  ID489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4  ID489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# 5  ID489434     22064           PINK DOUGHNUT TRINKET POT       24.0
# 6  ID489434     21871                  SAVE THE PLANET MUG      24.0
# 7  ID489434     21523   FANCY FONT HOME SWEET HOME DOORMAT      10.0
# 8  ID489435     22350                            CAT BOWL       12.0
# 9  ID489435     22349       DOG BOWL , CHASING BALL DESIGN      12.0
#
#           InvoiceDate  Price Customer ID         Country
# 0 2009-12-01 07:45:00   6.95     13085.0  United Kingdom
# 1                 NaT   6.75     13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75     13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10     13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25     13085.0  United Kingdom
# 5 2009-12-01 07:45:00   1.65     13085.0  United Kingdom
# 6 2009-12-01 07:45:00   1.25     13085.0  United Kingdom
# 7 2009-12-01 07:45:00   5.95     13085.0  United Kingdom
# 8 2009-12-01 07:46:00   2.55     13085.0  United Kingdom
# 9 2009-12-01 07:46:00   3.75     13085.0  United Kingdom

# %% [markdown]
# ### 1. Función para explorar características [0.5 puntos]

# %% [markdown]
# <p align="center">
#   <img width=300 src="https://editor.analyticsvidhya.com/uploads/47389meme.png">
# </p>

# %% [markdown]
# Tras inspeccionar brevemente los datos proporcionados, usted decide crear una función que realice lo siguiente:
# - Plotee un histograma para las variables precios y cantidad. [0.3 puntos]
# - Imprima un conteo de datos nulos por variable [0.2 puntos]
#
# **Nota**: Para generar los gráficos no es obligatorio el uso de `plotly`, pero si es altamente recomendado. Pueden encontrar más información de esta librería en este [enlace](https://plotly.com/python/).

# %% [markdown]
# **Respuesta:**

# %%
import matplotlib.pyplot as plt

def explorar_datos(df, max_price1 = 50,max_cant1 = 100,min_price = 0, min_cantn= 0,bin = 30,log_scale=False):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Filtrar valores muy grandes
    precios1 = df['Price'].dropna()
    precios= precios1[(precios1 >= min_price) & (precios1 <= max_price1)]


    
    cantidades1 = df['Quantity'].dropna()
    cantidades = cantidades1[(cantidades1 >= min_cantn) & (cantidades1 <= max_cant1)]

    # Histograma precios
    #max_price = precios.max()
    #num_bins_price = int(np.ceil(max_price))
    #bins_price = np.arange(0, num_bins_price + 1, 1)

    axes[0].hist(precios, bins=bin, edgecolor='black')
    axes[0].set_title("Histograma de Precios")
    axes[0].set_xlabel("Precio")
    axes[0].set_ylabel("Frecuencia")
    if log_scale:
        axes[0].set_xscale("log")

    # Histograma cantidades
    #max_cant = cantidades.max()
    #num_bins_cant = int(np.ceil(max_cant))
    #bins_cant = np.arange(0, num_bins_cant + 1, 1)
    axes[1].hist(cantidades, bins=bin, edgecolor='black')
    axes[1].set_title("Histograma de Cantidad")
    axes[1].set_xlabel("Cantidad")
    axes[1].set_ylabel("Frecuencia")
    if log_scale:
        axes[1].set_xscale("log")

    plt.tight_layout()
    plt.show()

    # Conteo de nulos
    print("Conteo de valores nulos por columna:")
    print(df.isnull().sum())

# %%
max_price = df_retail['Price'].max()
min_price = df_retail['Price'].min()
max_cant = df_retail['Quantity'].max()
min_cant = df_retail['Quantity'].min()
explorar_datos(df_retail,max_price1=max_price,max_cant1=max_cant,min_price=min_price,min_cantn=min_cant,bin=400)
# Out:
# Conteo de valores nulos por columna:
# Invoice           0
# StockCode         0
# Description       0
# Quantity       7915
# InvoiceDate    9308
# Price          8356
# Customer ID       0
# Country        8164
# dtype: int64

# %%
#Como existen muchos outliers es difil ver el histograma como esta, por eso definimos uno en que se hacen los histogramas hasta cierto valor,
#Para tener mejor entendimiento del data frame

explorar_datos(df_retail)
# Out:
# Conteo de valores nulos por columna:
# Invoice           0
# StockCode         0
# Description       0
# Quantity       7915
# InvoiceDate    9308
# Price          8356
# Customer ID       0
# Country        8164
# dtype: int64

# %% [markdown]
# ### 2. Eliminando outliers [1.0 puntos]

# %% [markdown]
# <p align="center">
#   <img width=300 src="https://media.licdn.com/dms/image/C5612AQGdXKCka7HumA/article-cover_image-shrink_600_2000/0/1520056407281?e=2147483647&v=beta&t=VZcfjjzjK4LxXdZkSu1KisWC0Ry8bk4tPCn3R8aYdNM">
# </p>

# %% [markdown]
# #### 2.1 Creando la clase IQR [0.5 puntos]

# %% [markdown]
# Entre las falencias de los datos, Mr. Cheems le comenta que a veces los operadores no ingresan el precio correcto de los productos. Mr. Cheems le comenta que se dio cuenta de este fenómeno porque hay productos con precios exagerádamente altos o bajos. Por lo cual usted decide eliminar outliers del dataframe a traves del rango intercuartil el cual cuenta con los siguientes pasos:
#
# 1. Calcular el primer cuartil $Q1$ y el tercer cuartil $Q3$. Hint: utilice el método `quantile()`
#
# 2. Calcular el rango intercuartil (RIC): $RIC = Q3 - Q1$
#
# 3. Calcular los límites para identificar outliers:
#  - Límite inferior: $~~Q1 - \lambda \cdot RIC$
#  - Límite superior: $~~Q3 + \lambda \cdot RIC$
#
# 4. Eliminar outliers: Los outliers son los datos que están por debajo del límite inferior o por encima del límite superior.
#
#
# Para realizar dicha tarea, usted decide crear una clase llamada `IQR()` utilizando `BaseEstimator` y `TransformerMixin` para realizar una transformación de cada una de las columnas numéricas del DataFrame utilizando `ColumnTransformer()` más tarde. Considere que lambda debe ser $\lambda$ un parámetro a definir por el usuario.
#
# **Hint:** tome como referencia el siguiente [enlace](https://sklearn-template.readthedocs.io/en/latest/user_guide.html#transformer).
#
# **Nota:** No modificar el método set_output de la clase IQR

# %% [markdown]
# **Respuesta:**

# %%
class IQR(BaseEstimator, TransformerMixin):

    def __init__(self, lmbda=1.5):
        self.lmbda = lmbda

    def fit(self, X):
        # Solo calculamos para columnas numéricas
        X_numeric = X.select_dtypes(include=np.number)
        self.Q1_ = X_numeric.quantile(0.25)
        self.Q3_ = X_numeric.quantile(0.75)
        self.RIC_ = self.Q3_ - self.Q1_
        self.lower_bound_ = self.Q1_ - self.lmbda * self.RIC_
        self.upper_bound_ = self.Q3_ + self.lmbda * self.RIC_
        return self

    def transform(self, X):
        X_out = X.copy()
        X_numeric = X_out.select_dtypes(include=np.number)

        X_out = X_numeric.clip(lower=self.lower_bound_, upper=self.upper_bound_, axis=1)

        return X_out

    def set_output(self, transform='default'):
        return self

# %%
IQR_class = IQR(lmbda=1.5)
IQR_class.fit(df_retail)
df_retailOut = IQR_class.transform(df_retail)
df_retailOut.shape
# Out:
# (400947, 2)

# %%
explorar_datos(df_retailOut)
# Out:
# Conteo de valores nulos por columna:
# Quantity    7915
# Price       8356
# dtype: int64

# %% [markdown]
# #### 2.2 Creación del Pipeline [0.5 puntos]

# %% [markdown]
# Para comenzar introduciéndose en el uso de pipeline, usted decide definir un pipeline con el Transformer previamente definido. Además, usted decide visualizar cómo cambia la distribución de las variables Precio y Cantidad antes y despues de aplicar IQR. Para ello, usted aplica los siguientes pasos:
#
# - Definir un pipeline llamado `numeric_transformations` para las variables precio y cantidad con la transformación IQR. [0.1 puntos]
# - Defina un column transformer que aplique `numeric_transformations` para las variables numéricas y `passthrough` para las variables categóricas. Adicionalmente, fije el parámetro `verbose_feature_names_out` en `False`. Ver hint al final [0.1 puntos]
# - Defina el dataframe `df_iqr` aplicado el column transformer a los datos proporcionados por Mr. Cheems considerando un valor de $\lambda$ que tenga un desempeño aceptable para ambas variables. [0.1 puntos]
# - Usar `explore_data` en `df_retail` y en `df_iqr`.  [0.1 puntos]
# - Reportar los cambios observados en la distribución de las variables. ¿Qué sucede al aumentar el valor de lambda? [0.1 puntos]
#
#
# **Hint:** El transformador `passthrough` está predefinido y es una opción que puedes usar para las columnas que no deseas transformar. Al especificar 'passthrough' para una parte de tu ColumnTransformer, las columnas correspondientes pasarán a través del ColumnTransformer sin ninguna modificación. El siguiente [enlace](https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html) le puede ser útil.
#
# **Nota:** Mantenga el método set_output del column transformer con la transformación `pandas` para obtener un dataframe una vez aplicado el column transformer.

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# Apóyese de la siguiente estructura para su respuesta:

# %%
# Definicion las variables que pasarán por cada pipeline
numerical_columns = ['Price', 'Quantity']
categorical_columns = ['Invoice', 'StockCode', 'Description', 'InvoiceDate', 'Customer ID', 'Country']

# Definicion del pipeline
numeric_transformations = Pipeline([
    ('iqr', IQR(lmbda=1.5))  
])
# ColumnTransformer
column_transformer = ColumnTransformer(
    transformers=[
        ('numerical', numeric_transformations, numerical_columns),
        ('categorical', 'passthrough', categorical_columns)
    ],
    verbose_feature_names_out=False
)

column_transformer.set_output(transform='pandas')


# ColumnTransformer a los datos
df_iqr = column_transformer.fit_transform(df_retail)


iqr_transformer = column_transformer.named_transformers_['numerical'].named_steps['iqr']

# Acceder a los límites inferior y superior para poder comparar despues los histogramas en el mismo intervalo de datos
iqr_min_q = iqr_transformer.lower_bound_['Quantity']
iqr_min_p = iqr_transformer.lower_bound_['Price']

iqr_max_q = iqr_transformer.upper_bound_['Quantity']
iqr_max_p = iqr_transformer.upper_bound_['Price']

# %%
explorar_datos(df_retail,
               max_price1=iqr_max_p,
               max_cant1=iqr_max_q,
               min_price=iqr_min_p,
               min_cantn=iqr_min_q)
# Out:
# Conteo de valores nulos por columna:
# Invoice           0
# StockCode         0
# Description       0
# Quantity       7915
# InvoiceDate    9308
# Price          8356
# Customer ID       0
# Country        8164
# dtype: int64

# %%
explorar_datos(df_iqr)
# Out:
# Conteo de valores nulos por columna:
# Price          8356
# Quantity       7915
# Invoice           0
# StockCode         0
# Description       0
# InvoiceDate    9308
# Customer ID       0
# Country        8164
# dtype: int64

# %% [markdown]
# *Reporte los cambios observados aquí.*
#
# Vemos primero que ahora los valores de ambas caracteristicas ahora tendran valores limites menores, que son los definidos a partir de los cuartiles. Ahora respecto a la distribucion de los datos, vemos que en aquellos datos que se encuentran entre los limites su distribucion, o frecuencia no cambia, pero, se observa que los valores limites aumentarn en frecuencia, debido a que se llevan los outliers. Respeecto a los valores de lamda, vemos que al aumentar su valor, la restriccion de los valores extremo disminuye, pudiendo ver que en especifico el limite superior aumenta, lo que genera que el aumento en frecuencia del valor maximo aumente menos en comparacion a los datos originales, a como lo hace con un lamda menor. Es decir, con un lamda mayor, el valor extremo que se genera aumentara menos su frecuencia, en comparacion al valor maximo obtenido con un lamda menor. Consideramos el valor lamda 1.5, ya que teoricamente es un valor usado, y respecto a nuestros datos vemos que da un desarrollo decente, visto del modo de que con estos valores, los valores mas extremos no se alejan tanto de la concentracion de datos, ya que vimos que con lamdas mas grandes, los valores mas extremos, y sus frecuencias, se alejaban bastante de donde estaban mas concentrados

# %% [markdown]
# ### 3. Agregando un imputer al pipeline [1.0 puntos]

# %% [markdown]
# <p align="center">
#   <img width=300 src="https://media.makeameme.org/created/hmm-there-is.jpg">
# </p>

# %% [markdown]
# Para continuar con la limpieza del dataframe usted decide imputar los datos nulos de las variables numéricas, para lo cual decide realizar las siguientes tareas:
#
# 1. Crear un pipeline para variables categóricas llamado `categoric_transformations` con un paso llamado `mode_imputer`, en el cual se imputen los datos faltantes por la categoría más frecuente.
# 2. Agregar al pipeline `numeric_transformations` un paso llamado `mean_imputer`, en el cual se imputen los datos por la media usando [SimpleImputer](https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html) [0.1 puntos]
# 3. Crear y aplicar un `ColumnTransformer` actualizado con los pipelines `categoric_transformations` y `numeric_transformations` a `df_retail`, creando un dataframe llamado `df_mean_imputer`. [0.1 puntos]
# 4. Comparar los resultados de `explore_data` en `df_mean_imputer` y `df_iqr`. ¿Qué diferencias observa en la distribución de los datos? [0.2 puntos]
# 5. Cambiar el imputer de `numeric_transformations` por [KNNImputer](https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html) y definir un nuevo dataframe llamado `df_knn_imputer`, aplicando el nuevo ColumnTransformer a `df_retail`. En caso de los tiempos de ejecución sean altos puede probar a reducir el parámetro `n_neighbors`. [0.1 puntos]
# 6. Comparar los resultados de `explore_data` en `df_knn_imputer` y `df_iqr`. ¿Qué diferencias observa en la distribución de los datos? [0.2 puntos]
# 7. Comparar los resultados de `explore_data` en `df_knn_imputer` y `df_mean_imputer`. ¿Cuál método de imputación es mejor? Deje el método escogido en el ColumnTransformer. [0.2 puntos]
#
# **Nota: Fije el parámetro verbose_feature_names_out en `False` y utilice el método set_output con transformación `pandas` en cada ColumnTransformer para obtener como salida un dataframe.**

# %% [markdown]
# **Respuesta:**

# %%
from sklearn.impute import SimpleImputer

# %%
numerical_columns = ['Quantity', 'Price']
categorical_columns = ['Invoice', 'StockCode', 'Description', 
                       'InvoiceDate', 'Customer ID', 'Country']

# %%
categoric_transformations = Pipeline([
    ('mode_imputer', SimpleImputer(strategy='most_frequent'))
])
numeric_transformations = Pipeline([
    ('iqr', IQR(lmbda=1.5)),                 
    ('mean_imputer', SimpleImputer(strategy='mean'))  
])

# %%
column_transformer = ColumnTransformer([
    ('numerical', numeric_transformations, numerical_columns),
    ('categorical', categoric_transformations, categorical_columns)
], verbose_feature_names_out=False)

column_transformer.set_output(transform='pandas')

# Aplicamos la transformación
df_mean_imputer = column_transformer.fit_transform(df_retail)

# %%
from sklearn.impute import KNNImputer

# %%
numeric_transformations_knn = Pipeline([
    ('iqr', IQR(lmbda=1.5)),
    ('knn_imputer', KNNImputer(n_neighbors=5))  
])

column_transformer_knn = ColumnTransformer([
    ('numerical', numeric_transformations_knn, numerical_columns),
    ('categorical', categoric_transformations, categorical_columns)
], verbose_feature_names_out=False)

column_transformer_knn.set_output(transform='pandas')

# Aplicamos la transformación
df_knn_imputer = column_transformer_knn.fit_transform(df_retail)

# %%
explorar_datos(df_mean_imputer)
# Out:
# Conteo de valores nulos por columna:
# Quantity       0
# Price          0
# Invoice        0
# StockCode      0
# Description    0
# InvoiceDate    0
# Customer ID    0
# Country        0
# dtype: int64

# %%
explorar_datos(df_knn_imputer)
# Out:
# Conteo de valores nulos por columna:
# Quantity       0
# Price          0
# Invoice        0
# StockCode      0
# Description    0
# InvoiceDate    0
# Customer ID    0
# Country        0
# dtype: int64

# %% [markdown]
# *Escriba su respuesta aquí*
#
# 4. Comparando la distribución de datos, no se puede ver ninguna diferencia entre estos dos.
#
# 6. Comparando la distribución del iqr y el knn imputer, no se pueden ver diferencias entre los dos gráficos
#
# 7. Comparando la distribución de knn y mean imputers, no se puede ver ninguna diferencia, pero de un punto de vista teorico, knn supone ser mejor ya que distribuye mejor los datos.

# %% [markdown]
# ### 4. Creación de nuevas features [2.0 puntos]

# %% [markdown]
# <p align="center">
#   <img width=250 src="https://miro.medium.com/max/1000/1*JtTWgAcfVTWV8OTjT47Atg.jpeg">
# </p>

# %% [markdown]
# #### 4.1 Definicion de LRMFP [1.0 puntos]

# %% [markdown]
# Dado que Mr. Lepin está interesado en obtener nuevos atributos relevantes para su negocio, su equipo de expertos sugiere la construcción de variables **LRMFP**, las que se construyen en base a las siguientes definiciones:
#
# - **Length (L)**: Intervalo de tiempo, en días, entre la primera y la última visita del cliente. Mientras mas grande sea el valor, mas fiel es el cliente.
#
# - **Recency (R)**: Indica hace cuanto tiempo el cliente realizo su ultima compra. Notar que para este caso, mientras mas grande es el valor, menos interes posee el usuario para repetir una compra en uno de los locales. **Considere "hoy" como la fecha mas reciente del dataset**.
#
# - **Monetary (M)**: El término "monetario" se refiere a la cantidad media de dinero gastada por cada visita del cliente durante el período de observación y refleja la contribución del cliente a los ingresos de la empresa.
#
# - **Frequency (F)**: Se refiere al número total de visitas del cliente durante el periodo de observación. Cuanto mayor sea la frecuencia, mayor será la fidelidad del cliente.
#
# - **Periodicity (P)**: Representa si los clientes visitan las tiendas con regularidad.
#
# $$Periodicity(n)=std(IVT_1, ..., IVT_n)$$
#
# Donde $IVT$ denota el tiempo entre visitas y n representa el número de valores de tiempo entre visitas de un cliente.
#
#
# $$IVT_i=date\_diff(t_{i+1},t)$$
#
# En base a las definiciones señaladas, diseñe una función que permita obtener las características **LRMFP** recibiendo un DataFrame como entrada. Para esto, no estará permitido el uso de iteradores, utilice todas las herramientas que les ofrece `pandas` para realizar esto.
#
# Una referencia que le puede ser útil es el [documento original](https://www.researchgate.net/publication/315979555_LRFMP_model_for_customer_segmentation_in_the_grocery_retail_industry_a_case_study) en donde se propone este método.

# %% [markdown]
# **<u>Formato</u> del Resultado Esperado:**
#
# | Customer ID | Length | Recency | Frequency | Monetary | Periodicity |
# |------------:|-------:|--------:|----------:|---------:|------------:|
# |   12346.0   |    294 |      67 |        46 |   -64.68 |        37.0 |
# |   12347.0   |     37 |       3 |        71 |  1323.32 |         0.0 |
# |   12349.0   |    327 |      43 |       107 |  2646.99 |        78.0 |
# |   12352.0   |     16 |      11 |        18 |   343.80 |         0.0 |
# |   12356.0   |     44 |      16 |        84 |  3562.25 |        12.0 |

# %% [markdown]
# **Respuesta:**

# %%
def custom_features(dataframe_in):
    dataframe_in['InvoiceDate'] = pd.to_datetime(dataframe_in['InvoiceDate'])

    clientes = dataframe_in.groupby('Customer ID')

    length = (clientes['InvoiceDate'].max() - clientes['InvoiceDate'].min()).dt.days

    hoy = dataframe_in['InvoiceDate'].max()

    Recency = (hoy - clientes['InvoiceDate'].max()).dt.days

    monetary = clientes['Price'].mean()

    frequency = clientes.size()

    #Ordenamos los valores por ID, y luego por fecha
    df_sorted = dataframe_in.sort_values(['Customer ID', 'InvoiceDate'])

    # Calcular diferencia de fechas entre visitas por cliente consecutivas
    #El primer elemento de la resta hace que para cada cliente, las fechas se muevan una fila hacia arriba
    #en cierta manera, hace referencia a la fecha siguiente, luego se resta la fecha actual, y dal el ivt
    df_sorted['IVT'] = (df_sorted.groupby('Customer ID')['InvoiceDate'].shift(-1) - df_sorted['InvoiceDate']).dt.days

    # Ahora calcular el std de esos IVT
    periodicity = df_sorted.groupby('Customer ID')['IVT'].std()

    


    features = pd.DataFrame({
        'Length': length,
        'Recency': Recency,
        'Monetary': monetary,
        'Frequency': frequency,
        'Periodicity': periodicity
    })

    return features.reset_index()
    
    
    pass

# %%
custom_features(df_retail)
# Out:
# /var/folders/dv/2lkcl0fn3wjgx7zy0djq3pkh0000gn/T/ipykernel_61359/36994844.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   clientes = dataframe_in.groupby('Customer ID')
# /var/folders/dv/2lkcl0fn3wjgx7zy0djq3pkh0000gn/T/ipykernel_61359/36994844.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sorted['IVT'] = (df_sorted.groupby('Customer ID')['InvoiceDate'].shift(-1) - df_sorted['InvoiceDate']).dt.days
# /var/folders/dv/2lkcl0fn3wjgx7zy0djq3pkh0000gn/T/ipykernel_61359/36994844.py:25: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   periodicity = df_sorted.groupby('Customer ID')['IVT'].std()
#      Customer ID  Length  Recency  Monetary  Frequency  Periodicity
# 0        12346.0   196.0    164.0  6.253333         33    22.055112
# 1        12347.0    37.0      2.0  2.164493         71     4.486909
# 2        12348.0     0.0     73.0  0.719500         20     0.000000
# 3        12349.0   181.0     42.0  8.577400        102    16.281613
# 4        12351.0     0.0     10.0  2.355238         21     0.000000
# ...          ...     ...      ...       ...        ...          ...
# 4309     18283.0   275.0     17.0  2.211887        217    11.893574
# 4310     18284.0     0.0     66.0  3.279259         28     0.000000
# 4311     18285.0     0.0    295.0  8.350000         12     0.000000
# 4312     18286.0   247.0    111.0  4.280806         67    30.636579
# 4313     18287.0   188.0     17.0  2.875783         85    15.483554
#
# [4314 rows x 6 columns]

# %% [markdown]
# #### 4.2 Agregando las custom features [1.0 puntos]

# %% [markdown]
# Ahora, usted decide agregar al pipeline las nuevas variables creadas, para lo cual realiza las siguientes tareas:
#
# 1. Cree un nuevo pipeline llamado `retail_pipeline` que encapsule el ColumnTransformer y calcule las LRMFP. El primer paso del pipeline llámelo  `col_tranformer` y el segundo paso llámelo `custom_features`, incorpora las nuevas variables al dataframe. Hint: les puede ser útil investigar [este](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html) método. [0.1 puntos]
# 2. Aplicar el pipeline actualizado a los datos proporcionados por Mr. Cheems, creando un nuevo dataframe llamado `df_custom`. [0.1 puntos]
# 3. Explorar la distribución de las nuevas variables con `explore_data` y comentar brevemente (2-3 líneas) características de cada custom feature. [0.5 puntos]
# 5. Entregar un insight para el negocio en base a las nuevas variables. [0.3 puntos]
#
# **Nota:** Recuerde fijar el parámetro `verbose_feature_names_out` en `False` e incorporar el método `set_output` para obtener una salida en formato dataframe del ColumnTransformer.

# %% [markdown]
# **Respuesta**

# %%
from sklearn.preprocessing import FunctionTransformer

custom_feat_transformer = FunctionTransformer(custom_features)

retail_pipeline = Pipeline([
    ('col_transformer', column_transformer),
    ('custom_features', custom_feat_transformer)
])

df_custom = retail_pipeline.fit_transform(df_retail)

# %%
def explorar_lrmfp(df, 
                   max_length=100000, max_recency=100000, 
                   max_monetary=100000, max_frequency=50000, 
                   max_periodicity=50000,
                   log_scale=False):
    
    fig, axes = plt.subplots(1, 5, figsize=(22, 5))

    
    variables = [
        ('Length', max_length),
        ('Recency', max_recency),
        ('Monetary', max_monetary),
        ('Frequency', max_frequency),
        ('Periodicity', max_periodicity)
    ]

    for i, (col, max_val) in enumerate(variables):
        if col not in df.columns:
            continue  # en caso de que alguna variable no exista

        data_raw = df[col].dropna()
        #data = data_raw[(data_raw > 0) & (data_raw <= max_val)]
        data = data_raw

        max_bin = data.max()
        num_bins = int(np.ceil(max_bin))
        bins = np.arange(0, num_bins + 1, 1)

        axes[i].hist(data, bins=bins, edgecolor='black')
        axes[i].set_title(f"Histograma de {col}")
        axes[i].set_xlabel(col)
        axes[i].set_ylabel("Frecuencia")
        if log_scale:
            axes[i].set_xscale("log")

    plt.tight_layout()
    plt.show()

    # Conteo de nulos
    print("Conteo de valores nulos por columna:")
    print(df[[v[0] for v in variables if v[0] in df.columns]].isnull().sum())

# %%
explorar_lrmfp(df_custom)
# Out:
# Conteo de valores nulos por columna:
# Length           0
# Recency          0
# Monetary         0
# Frequency        0
# Periodicity    148
# dtype: int64

# %% [markdown]
# Respecto a la variable length, vemos que existe una gran cantidad de clientes que solo han ido una vez, es decir su lenght es 0, mientras que muchos clientes tienen la diferencia entre su ultima y primera visita en torno a los 250 dias. Respecto a la frecuncia, vemos que la mayoria de clientes realizo su ultima compra en los iltimos 3 meses, por lo que se puede esperar mas interes de ellos, y, del grafico, podemos observar que hace una cantidad especifica de dias, en torno a 280 dias atras, hubo un gran cantidad de compras de clientes, que fue su ultima compra, lo que puede hacer suponer que ese fue un dia especial o festivo, en que habia mayor demanda de los productos. Respecto a la cantidad gastada, vemos que esta sigue una distribucion similar a una normal, centrada en 2.5. Respecto a la frecuancia, vemos que la mayoria de los clientes ha visitado la tienda entre 0 y 1000 veces en el ultimo tiempo. Respecto a la peridiocity, vemos que la mayoria de los clientes estan en entre 0 y 50.

# %% [markdown]
# Respecto a las variables, el negocio deberia encontrar la manera de mantener a los clientes, ya que vemos que para muchos clientes, la diferencia entre su ultima y primera compra es 0, lo que indica que no se quedan como clientes. Dado el gasto promedio de los clientes, lo ideal seria trabajar con productos que esten en ese orden de precios, ya que serian mas probables de vender que productos mas caros, pudiendo aumentar asi ingresos. Respectp a la peridiocidad, vemos que si bien existen hartos valores que estan cercanos al 0, estos se pueden deber a como se trabajo los valores nulos, que darian desviacion 0, pero si nos centramos en los otros valores, vemos que la desviacion esta en torno a los 10 o 15 dias, lo que muestra que si bien es frecuenta la visita, esta se podria aumentar poniendo eventos o motivos que favorezcan visitas semanales, o bisemanales.

# %% [markdown]
# ### 5. MinMax Scaler [1.0 puntos]

# %% [markdown]
# <p align="center">
#   <img width=300 src="https://i.imgflip.com/1fsprn.jpg">
# </p>

# %% [markdown]
# #### 5.1 Definición del Column Transformer [0.5 puntos]

# %% [markdown]
# Construya una clase llamada `MinMax()` para realizar una transformación de cada una de las columnas de un DataFrame utilizando `ColumnTransformer()`. Recuerde  usar `BaseEstimator` y `TransformerMixin`.
#
#
#  Para esto considere que Min-Max escaler queda dada por la ecuación:
#
# $$MinMax = \dfrac{x-min(x)}{max(x) - min(x)}$$
#
#
# Consulte el siguiente [link](https://sklearn-template.readthedocs.io/en/latest/user_guide.html#transformer) si tiene dudas sobre la creación de custom transformers.

# %% [markdown]
# **Respuesta:**

# %%
class MinMax(BaseEstimator, TransformerMixin):

    def fit(self,X,y=None):
        X_numeric = X.select_dtypes(include=np.number)
        self.x_min_ = X_numeric.min()
        self.x_max_ = X_numeric.max()
        return self
        
        pass

    def transform(self,X):
        #Agregar código aquí
        X_out = X.copy()
        X_numeric = X_out.select_dtypes(include=np.number)
        x_minmax = (X_numeric - self.x_min_)/(self.x_max_ - self.x_min_)
        X_out[X_numeric.columns] = x_minmax
        return X_out
        pass

    def set_output(self,transform='default'):
        #No modificar este método
        return self

# %% [markdown]
# #### 5.2 Incorporando MinMax al pipeline [0.5 puntos]

# %% [markdown]
# Ahora, usted decide agregar el escalamiento al pipeline, para lo que decide seguir los siguientes pasos:
#
# - Agregar el paso `minmax` al pipeline `numeric_transformations`, haciendo uso de la clase creada. [0.1 puntos]
# - Defina el dataframe `df_minmax` aplicando el ColumnTransformer actualizado a los datos proporcionados por Mr. Cheems. [0.1 puntos]
# - Usar `explore_data` en `df_retail` y en `df_minmax`. [0.1 puntos]
# - Reportar los cambios observados en la distribución de las variables.  [0.2 puntos]
#
# **Nota:** Recuerde fijar el parámetro `verbose_feature_names_out` en `False` e incorporar el método `set_output` para obtener una salida en formato dataframe del ColumnTransformer.

# %% [markdown]
# **Respuesta:**

# %%
numeric_transformations = Pipeline([
    ('iqr', IQR(lmbda=1.5)),                 
    ('mean_imputer', SimpleImputer(strategy='mean')) ,
    ('minmax', MinMax())
])

column_transformer = ColumnTransformer([
    ('numerical', numeric_transformations, numerical_columns),
    ('categorical', categoric_transformations, categorical_columns)
], verbose_feature_names_out=False)

column_transformer.set_output(transform='pandas')

# Aplicamos la transformación
df_minmax = column_transformer.fit_transform(df_retail)

# %%
explorar_datos(df_minmax)
# Out:
# Conteo de valores nulos por columna:
# Quantity       0
# Price          0
# Invoice        0
# StockCode      0
# Description    0
# InvoiceDate    0
# Customer ID    0
# Country        0
# dtype: int64

# %%
explorar_datos(df_retail,
               max_price1=iqr_max_p,
               max_cant1=iqr_max_q,
               min_price=iqr_min_p,
               min_cantn=iqr_min_q)
# Out:
# Conteo de valores nulos por columna:
# Invoice           0
# StockCode         0
# Description       0
# Quantity       7915
# InvoiceDate    9308
# Price          8356
# Customer ID       0
# Country        8164
# dtype: int64

# %% [markdown]
# Al realizar una comparación entre retail y minmax podemos ver que hay un cambio significativo entre estos dos, pero manteniendo la estructura, la principal diferencia que se puede ver es que los datos del minmax distribuyen a traves de todo el gráfico, ajustandose al rango de 0 y 1, de esta forma los valores presentes en retail son más interpretable. Esto se debe a la formula del minmax, ya que los datos que cuenten con una diferencia alta entre max(x) y min(x), se verán distribuidos más cercanos a cero, y a medida que la diferencia disminuye del min(x) y max(x), se van acercando a 1

# %% [markdown]
# ### 6. Pregunta teórica [0.5 puntos]

# %% [markdown]
# <p align="center">
#   <img width=300 src="https://file.coinexstatic.com/2023-09-19/166BAC031F222E5910954E7D7D0BC844.png">
# </p>

# %% [markdown]
# Finalmente, explíquele a Mr. Cheems porqué es útil la creación de pipelines al momento de hacer Feature Engineering en Machine Learning.

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# Bueno señor cheems, para el feature engineering, es decir la preparación y la transformación de datos, es importante ser consistente ya que se tiene que poder preparar los datos de entrenamiento y de testeo la misma forma, y si se quisiera cambiar el modelo, o actualizar la data es importante poder replicarlo exactamente de la misma manera y de forma segura. Es como una linea de producción, que asegura que el producto sea de una forma, incluso con nuevos datos, y ademas se puede hacer de forma rapida y eficiente cada vez.
