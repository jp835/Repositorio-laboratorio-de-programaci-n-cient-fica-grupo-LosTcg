# %%
from prepare_data import build_datasets_callable
build_datasets_callable(
    clientes_path='data/clientes.parquet',
    productos_path='data/productos.parquet',
    transacciones_path='data/transacciones.parquet',
    train_output_path='data/processed/df_train.parquet',
    predict_output_path='data/processed/df_predict.parquet'
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from prepare_data import build_datasets_callable
#       2 build_datasets_callable(
#       3     clientes_path='data/clientes.parquet',
#       4     productos_path='data/productos.parquet',
#    (...)      7     predict_output_path='data/processed/df_predict.parquet'
#       8 )
#
# ModuleNotFoundError: No module named 'prepare_data'
